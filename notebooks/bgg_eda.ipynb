# %% [markdown]
# # Imports and Paths

# %%
import pandas as pd
from pymongo import MongoClient

# %%
db = MongoClient()['bgg']['game_info']

# %%
db.find_one()
# Out:
# {'_id': ObjectId('5c2130c151363053da005cd5'),
#  'name': 'Gloomhaven',
#  'game_id': '174430',
#  'url': 'https://boardgamegeek.com/boardgame/174430/gloomhaven',
#  'yearpublished': '2017',
#  'minplayers': '1',
#  'maxplayers': '4',
#  'playingtime': '120',
#  'minplaytime': '60',
#  'maxplaytime': '120',
#  'minage': '12',
#  'numplayers': {'1': {'Best': 68, 'Recommended': 248, 'Not Recommended': 122},
#   '2': {'Best': 130, 'Recommended': 325, 'Not Recommended': 36},
#   '3': {'Best': 279, 'Recommended': 197, 'Not Recommended': 11},
#   '4': {'Best': 195, 'Recommended': 233, 'Not Recommended': 49},
#   '4+': {'Best': 2, 'Recommended': 22, 'Not Recommended': 306}},
#  'boardgamecategory': ['Adventure',
#   'Exploration',
#   'Fantasy',
#   'Fighting',
#   'Miniatures'],
#  'boardgamemechanic': ['Campaign / Battle Card Driven',
#   'Cooperative Play',
#   'Grid Movement',
#   'Hand Management',
#   'Modular Board',
#   'Role Playing',
#   'Simultaneous Action Selection',
# ...
